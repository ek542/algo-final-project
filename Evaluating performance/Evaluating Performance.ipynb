# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Defining a function to evaluate clustering algorithm performances

# %%
############################################################################################
# 
# Inputs
#
# cluster_labels --> a numpy array containing cluster labels for people
# in the order of the original file
#
# hand_label_info --> the dataframe version of 'okcupid-cleaned-dropped-10k-handlabels.csv'
#
# ==========================================================================================
# 
# Outputs (in order)
#
# sim_count --> the number of pairs (out of 50) which are correctly 
# assigned to the same cluster
# 
# dissim_count --> the number of pairs (out of 51) which are correctly
# assigned to different clusters
#
############################################################################################


def eval_performance(cluster_labels, hand_label_info):
    
    # add the row number to each row of the hand_label_info df
    hand_label_info['index'] = range(0, len(hand_label_info))
    
    # get all 202 rows that have labels
    labeled_rows = hand_label_info[~hand_label_info['hand-label'].isnull()]
    
    # get all 100 rows with similar pairs of people
    sim = labeled_rows[labeled_rows['hand-label'].str.isnumeric()]
    
    # get all 102 rows with dissimilar pairs of people
    dissim = labeled_rows[~labeled_rows['hand-label'].str.isnumeric()]
    
    # sort both so similar / dissimilar pairs are consecutive
    sim = sim.sort_values(by=['hand-label'])
    dissim = dissim.sort_values(by=['hand-label'])
    
    # count the number of similar people who ended up in the same cluster
    
    # loop through every pair of similar people
    
    i = 0
    sim_count = 0
    
    while i + 1 < len(sim):
        
        person1 = sim.iloc[i]
        person2 = sim.iloc[i+1]
        
        # get the (original) row number associated with each person
        index1 = person1['index']
        index2 = person2['index']
        
        # increment the count if the two people's cluster assignments are the same
        if cluster_labels[index1] == cluster_labels[index2]:
            sim_count += 1
        
        # move to the next pair
        i += 2
 
    
    # count the number of dissimilar people who ended up in different clusters
    
    # loop through every pair of dissimilar people
    
    j = 0
    dissim_count = 0
    
    while j + 1 < len(dissim):
        
        person1 = dissim.iloc[j]
        person2 = dissim.iloc[j+1]
        
        # get the (original) row number associated with each person
        index1 = person1['index']
        index2 = person2['index']
        
        # increment the count if the two people's cluster assignments are different
        if cluster_labels[index1] != cluster_labels[index2]:
            dissim_count += 1
        
        # move to the next pair
        j += 2
        
    # print the performance 
    print(str(sim_count) + " out of 50 or " + str(round((sim_count/50)*100, 2)) + "% of similar pairs were in the same cluster")
    print(str(dissim_count) + " out of 51 or " + str(round((dissim_count/51)*100, 2)) + "% of dissimilar pairs were in different clusters")
    
    return sim_count, dissim_count

# %% [markdown]
# ## Evaluating K-means performance

# %%
# Using the function with Andrew's K-means output

# loading cluster labels
kmeans_cluster_labels = ((pd.read_csv('12_15_kmeans_label.csv'))['0']).to_numpy()
display(kmeans_cluster_labels)

# loading hand label info
hand_label_info = pd.read_csv('okcupid-cleaned-dropped-10k-handlabels.csv')
display(hand_label_info)

eval_clustering_performance(kmeans_cluster_labels, hand_label_info)
# Out:
# array([11, 42, 36, ..., 41, 49,  6])
#        Unnamed: 0   age  sex orientation  body_type        diet  drinks  \
# 0         30518.0  26.0    f    straight        5.0       vegan     2.0
# 1         56256.0  38.0    f    straight        5.0    anything     2.0
# 2         31846.0  38.0    m    straight        5.0    anything     3.0
# 3         38659.0  38.0    f    straight        4.0    anything     0.0
# 4         20309.0  24.0    f         gay        4.0    anything     2.0
# ...           ...   ...  ...         ...        ...         ...     ...
# 9996      32132.0  22.0    f    bisexual        5.0  vegetarian     2.0
# 9997       8119.0  22.0    m    straight        5.0    anything     2.0
# 9998       7887.0  20.0    f    straight        2.0       other     1.0
# 9999      13868.0  27.0    f    straight        2.0    anything     2.0
# 10000         NaN   NaN  NaN         NaN        NaN         NaN     NaN
#
#            drugs                          education ethnicity  ...  \
# 0      sometimes  graduated from college/university     white  ...
# 1          never                    working on grad     white  ...
# 2          never  graduated from college/university     white  ...
# 3          never  graduated from college/university     asian  ...
# 4      sometimes         graduated from high school     white  ...
# ...          ...                                ...       ...  ...
# 9996   sometimes  graduated from college/university     black  ...
# 9997   sometimes      working on college/university     white  ...
# 9998       never      working on college/university     mixed  ...
# 9999       never  graduated from college/university     white  ...
# 10000        NaN                                NaN       NaN  ...
#
#        portuguese russian spanish turkish has kids wants kids likes dogs  \
# 0              no      no     yes      no       no        yes        yes
# 1              no      no      no      no       no         no        yes
# 2              no      no      no      no       no         no         no
# 3              no      no      no      no       no         no         no
# 4              no      no      no      no       no         no         no
# ...           ...     ...     ...     ...      ...        ...        ...
# 9996           no      no      no      no       no         no        yes
# 9997           no      no      no      no       no         no        yes
# 9998           no      no      no      no       no        yes        yes
# 9999           no      no      no      no       no         no        yes
# 10000         NaN     NaN     NaN     NaN      NaN        NaN        NaN
#
#       likes cats  new_religion hand-label
# 0            yes   agnosticism          T
# 1             no          none        NaN
# 2             no          none        NaN
# 3             no   catholicism        NaN
# 4             no         other        NaN
# ...          ...           ...        ...
# 9996          no          none        NaN
# 9997         yes   agnosticism        NaN
# 9998          no  christianity        NaN
# 9999          no          none        NaN
# 10000        NaN           NaN        NaN
#
# [10001 rows x 32 columns]
# 16 out of 50 or 32.0% of similar pairs were in the same cluster
# 51 out of 51 or 100.0% of dissimilar pairs were in different clusters
# (16, 51)

# %% [markdown]
# ## Defining a function to evaluate K-nearest neighbor algorithm performances

# %%
############################################################################################
# 
# Inputs
#
# neighbor_matrix --> a numpy matrix with dimensions n x n where n is the number of peeps
# neighbor_matrix[i][j] = 1 if the person at index j is a neighbor of the person at index i
#
# hand_label_info --> the dataframe version of 'okcupid-cleaned-dropped-10k-handlabels.csv'
#
# ==========================================================================================
# 
# Outputs (in order)
#
# sim_count --> the number of pairs (out of 50) which are correctly 
# assigned to the same cluster
# 
# dissim_count --> the number of pairs (out of 51) which are correctly
# assigned to different clusters
#
############################################################################################


def eval_neighbors_performance(neighbor_matrix, hand_label_info):
    
    # add the row number to each row of the hand_label_info df
    hand_label_info['index'] = range(0, len(hand_label_info))
    
    # get all 202 rows that have labels
    labeled_rows = hand_label_info[~hand_label_info['hand-label'].isnull()]
    
    # get all 100 rows with similar pairs of people
    sim = labeled_rows[labeled_rows['hand-label'].str.isnumeric()]
    
    # get all 102 rows with dissimilar pairs of people
    dissim = labeled_rows[~labeled_rows['hand-label'].str.isnumeric()]
    
    # sort both so similar / dissimilar pairs are consecutive
    sim = sim.sort_values(by=['hand-label'])
    dissim = dissim.sort_values(by=['hand-label'])
    
    # count the number of similar people who ended up in the same cluster
    
    # loop through every pair of similar people
    
    i = 0
    sim_count = 0
    
    while i + 1 < len(sim):
        
        person1 = sim.iloc[i]
        person2 = sim.iloc[i+1]
        
        # get the (original) row number associated with each person
        index1 = person1['index']
        index2 = person2['index']
        
        # increment the count if the two people's cluster assignments are the same
        if neighbor_matrix[index1][index2] == 1:
            sim_count += 1
        
        # move to the next pair
        i += 2
 
    
    # count the number of dissimilar people who ended up in different clusters
    
    # loop through every pair of dissimilar people
    
    j = 0
    dissim_count = 0
    
    while j + 1 < len(dissim):
        
        person1 = dissim.iloc[j]
        person2 = dissim.iloc[j+1]
        
        # get the (original) row number associated with each person
        index1 = person1['index']
        index2 = person2['index']
        
        # increment the count if the two people's cluster assignments are different
        if neighbor_matrix[index1,index2] != 1:
            dissim_count += 1
        
        # move to the next pair
        j += 2
        
    # print the performance 
    print(str(sim_count) + " out of 50 or " + str(round((sim_count/50)*100, 2)) + "% of similar pairs were in the same cluster")
    print(str(dissim_count) + " out of 51 or " + str(round((dissim_count/51)*100, 2)) + "% of dissimilar pairs were in different clusters")
    
    return sim_count, dissim_count

# %% [markdown]
# ## Evaluating K nearest neighbors (using Gower distance) performance

# %%
from sklearn.neighbors import NearestNeighbors
import gower

train_df = pd.read_csv('okcupid-cleaned-dropped-10k-handlabels.csv')
train_df = train_df.drop(['sex', 'orientation', 'Unnamed: 0', 'hand-label'], axis=1)
train_df = train_df[:-1]

print(train_df.columns[train_df.isna().any()].tolist())

dist_matrix = gower.gower_matrix(train_df)

neigh = NearestNeighbors(n_neighbors=50, metric="precomputed")
neigh.fit(dist_matrix)

neighbor_matrix = (neigh.kneighbors_graph(mode="distance")).toarray()
# Out:
# []

# %%
eval_neighbors_performance(neighbor_matrix, hand_label_info)
# Out:
# 0 out of 50 or 0.0% of similar pairs were in the same cluster
# 51 out of 51 or 100.0% of dissimilar pairs were in different clusters
# (0, 51)

# %%
indices = np.nonzero(neighbor_matrix[1917])
hand_label_info['index'] = range(0, len(hand_label_info))

print(hand_label_info.iloc[indices[0][1]])

display(hand_label_info.iloc[indices])
# Out:
# Unnamed: 0                                58115.0
# age                                          30.0
# sex                                             f
# orientation                              straight
# body_type                                     5.0
# diet                                     anything
# drinks                                        2.0
# drugs                                       never
# education       graduated from college/university
# ethnicity                                   white
# height                                       69.0
# job                             medicine / health
# sign                              does_not_matter
# smokes                                         no
# arabic                                         no
# chinese                                        no
# english                                       yes
# german                                         no
# hindi                                          no
# italian                                        no
# japanese                                       no
# korean                                         no
# portuguese                                     no
# russian                                        no
# spanish                                        no
# turkish                                        no
# has kids                                       no
# wants kids                                     no
# likes dogs                                    yes
# likes cats                                     no
# new_religion                          agnosticism
# hand-label                                    NaN
# index                                         305
# Name: 305, dtype: object
#       Unnamed: 0   age sex orientation  body_type      diet  drinks  \
# 180       1553.0  31.0   m    straight        5.0  anything     2.0
# 305      58115.0  30.0   f    straight        5.0  anything     2.0
# 417      24638.0  29.0   m    straight        3.0  anything     2.0
# 1104     12655.0  31.0   m    straight        5.0  anything     2.0
# 1343     12300.0  48.0   m    straight        5.0  anything     2.0
# 1365     56266.0  33.0   m    straight        5.0  anything     2.0
# 1619      1693.0  28.0   m    straight        5.0  anything     2.0
# 1670     38692.0  30.0   m    straight        5.0  anything     2.0
# 1731     58374.0  25.0   m    straight        5.0  anything     2.0
# 1996     50306.0  27.0   f    straight        5.0  anything     2.0
# 2028     42751.0  34.0   m    straight        5.0  anything     2.0
# 2253     17617.0  24.0   m    straight        5.0  anything     2.0
# 3004     46330.0  33.0   f    straight        5.0  anything     2.0
# 3056     46345.0  32.0   f    straight        5.0  anything     2.0
# 3494     51200.0  28.0   m    straight        5.0  anything     2.0
# 4162     32000.0  30.0   f    straight        5.0  anything     2.0
# 4194     27784.0  35.0   m    straight        5.0  anything     2.0
# 4340     15125.0  30.0   m    straight        5.0  anything     2.0
# 4505     38007.0  24.0   m    straight        5.0  anything     2.0
# 4698     13918.0  25.0   m    straight        5.0  anything     2.0
# 4855     23076.0  27.0   m    straight        5.0  anything     2.0
# 4896     53218.0  45.0   m    straight        5.0  anything     2.0
# 5112     31277.0  44.0   f    straight        5.0  anything     2.0
# 5134     35055.0  40.0   m    straight        5.0  anything     2.0
# 5150      6805.0  26.0   m         gay        5.0  anything     2.0
# 5494     48405.0  26.0   m    straight        5.0  anything     2.0
# 5956     25194.0  31.0   f    straight        5.0  anything     2.0
# 6022     45390.0  33.0   m    straight        5.0  anything     2.0
# 6090     19773.0  37.0   m    straight        5.0  anything     2.0
# 6310     10982.0  33.0   f    straight        4.0  anything     2.0
# 6988      6456.0  27.0   m    straight        5.0  anything     2.0
# 7234      7155.0  45.0   f    straight        5.0  anything     2.0
# 7416      8300.0  39.0   m    straight        5.0  anything     2.0
# 7484     38052.0  25.0   f    straight        5.0  anything     2.0
# 7642     29247.0  42.0   m    straight        5.0  anything     2.0
# 8129     15337.0  44.0   f    straight        5.0  anything     2.0
# 8352     48352.0  24.0   m    straight        5.0  anything     2.0
# 8565     26259.0  37.0   f    straight        5.0  anything     2.0
# 8722     18140.0  31.0   m    straight        5.0  anything     2.0
# 8870      1735.0  31.0   m    straight        5.0  anything     2.0
# 9111     37852.0  23.0   m    straight        5.0  anything     2.0
# 9258     25386.0  48.0   f    straight        5.0  anything     2.0
# 9336     52114.0  29.0   m         gay        5.0  anything     2.0
# 9368     19415.0  45.0   f    straight        3.0  anything     2.0
# 9497     16507.0  32.0   m         gay        5.0  anything     2.0
# 9739     22604.0  27.0   m    straight        5.0  anything     2.0
# 9803     32540.0  35.0   f    straight        5.0  anything     2.0
# 9861     17654.0  34.0   m    straight        5.0  anything     2.0
# 9886     12907.0  39.0   m    straight        5.0  anything     2.0
# 9910     43359.0  30.0   m    straight        5.0  anything     2.0
#
#           drugs                          education ethnicity  ...  russian  \
# 180       never  graduated from college/university     white  ...       no
# 305       never  graduated from college/university     white  ...       no
# 417       never  graduated from college/university     white  ...       no
# 1104      never  graduated from college/university     white  ...       no
# 1343      never  graduated from college/university     white  ...       no
# 1365      never  graduated from college/university     white  ...       no
# 1619      never  graduated from college/university     white  ...       no
# 1670      never  graduated from college/university     asian  ...       no
# 1731      never  graduated from college/university     white  ...       no
# 1996      never  graduated from college/university     white  ...       no
# 2028      never  graduated from college/university     white  ...       no
# 2253      never  graduated from college/university     white  ...       no
# 3004  sometimes  graduated from college/university     white  ...       no
# 3056      never  graduated from college/university     white  ...       no
# 3494      never  graduated from college/university     white  ...       no
# 4162      never  graduated from college/university     white  ...       no
# 4194      never  graduated from college/university     white  ...       no
# 4340      never  graduated from college/university     white  ...       no
# 4505      never  graduated from college/university     white  ...       no
# 4698      never  graduated from college/university     white  ...       no
# 4855      never  graduated from college/university     white  ...       no
# 4896      never  graduated from college/university     white  ...       no
# 5112      never  graduated from college/university     white  ...       no
# 5134      never  graduated from college/university     white  ...       no
# 5150      never  graduated from college/university     white  ...       no
# 5494      never  graduated from college/university     white  ...       no
# 5956      never  graduated from college/university     white  ...       no
# 6022      never  graduated from college/university     asian  ...       no
# 6090      never  graduated from college/university     white  ...       no
# 6310      never  graduated from college/university     white  ...       no
# 6988      never  graduated from college/university     white  ...       no
# 7234      never  graduated from college/university     white  ...       no
# 7416      never  graduated from college/university     white  ...       no
# 7484      never  graduated from college/university     white  ...       no
# 7642      never  graduated from college/university     white  ...       no
# 8129      never  graduated from college/university     white  ...       no
# 8352      never  graduated from college/university     white  ...       no
# 8565      never  graduated from college/university     white  ...       no
# 8722      never  graduated from college/university     white  ...       no
# 8870      never  graduated from college/university     white  ...       no
# 9111      never  graduated from college/university     white  ...       no
# 9258      never  graduated from college/university     white  ...       no
# 9336      never  graduated from college/university     white  ...       no
# 9368      never  graduated from college/university     white  ...       no
# 9497      never  graduated from college/university     white  ...       no
# 9739  sometimes  graduated from college/university     white  ...       no
# 9803      never  graduated from college/university     white  ...       no
# 9861      never  graduated from college/university     white  ...       no
# 9886      never  graduated from college/university     white  ...       no
# 9910      never  graduated from college/university     white  ...       no
#
#      spanish turkish has kids wants kids likes dogs likes cats  new_religion  \
# 180       no      no       no         no        yes         no          none
# 305       no      no       no         no        yes         no   agnosticism
# 417       no      no       no         no        yes         no          none
# 1104      no      no       no         no        yes         no          none
# 1343      no      no       no         no        yes         no   catholicism
# 1365      no      no       no         no        yes         no          none
# 1619      no      no       no         no        yes         no          none
# 1670      no      no       no         no        yes         no          none
# 1731      no      no       no         no        yes         no   catholicism
# 1996      no      no       no         no        yes         no   catholicism
# 2028      no      no       no         no        yes         no       atheism
# 2253      no      no       no         no        yes         no   agnosticism
# 3004      no      no       no         no        yes         no   agnosticism
# 3056      no      no       no         no        yes         no  christianity
# 3494      no      no       no         no        yes         no  christianity
# 4162      no      no       no         no        yes         no          none
# 4194      no      no       no         no        yes         no       judaism
# 4340      no      no       no         no        yes         no   agnosticism
# 4505      no      no       no         no        yes         no   catholicism
# 4698      no      no       no         no        yes         no       judaism
# 4855      no      no       no         no        yes         no       atheism
# 4896      no      no       no         no        yes         no       atheism
# 5112      no      no       no         no        yes         no   catholicism
# 5134      no      no       no         no        yes         no          none
# 5150      no      no       no         no        yes         no          none
# 5494      no      no       no         no        yes         no          none
# 5956      no      no       no         no        yes         no       judaism
# 6022      no      no       no         no        yes         no   catholicism
# 6090      no      no       no         no        yes        yes         other
# 6310      no      no       no         no        yes         no          none
# 6988      no      no       no         no        yes         no   catholicism
# 7234      no      no       no         no        yes         no         other
# 7416      no      no       no         no        yes         no          none
# 7484      no      no       no         no        yes         no          none
# 7642      no      no       no         no        yes        yes       judaism
# 8129      no      no       no         no        yes         no   catholicism
# 8352      no      no       no         no        yes         no  christianity
# 8565      no      no       no         no        yes        yes   catholicism
# 8722      no      no       no         no        yes         no          none
# 8870      no      no       no         no        yes         no       atheism
# 9111      no      no       no         no        yes         no       atheism
# 9258      no      no       no         no        yes         no          none
# 9336      no      no       no         no        yes         no          none
# 9368      no      no       no         no        yes         no         other
# 9497      no      no       no         no        yes         no          none
# 9739      no      no       no         no        yes         no       judaism
# 9803      no      no       no         no        yes         no   catholicism
# 9861      no      no       no         no        yes         no       judaism
# 9886      no      no       no         no        yes         no   agnosticism
# 9910      no      no       no         no        yes         no  christianity
#
#      hand-label index
# 180         NaN   180
# 305         NaN   305
# 417         NaN   417
# 1104        NaN  1104
# 1343        NaN  1343
# 1365        NaN  1365
# 1619        NaN  1619
# 1670        NaN  1670
# 1731        NaN  1731
# 1996        NaN  1996
# 2028        NaN  2028
# 2253        NaN  2253
# 3004        NaN  3004
# 3056        NaN  3056
# 3494        NaN  3494
# 4162        NaN  4162
# 4194        NaN  4194
# 4340        NaN  4340
# 4505        NaN  4505
# 4698        NaN  4698
# 4855        NaN  4855
# 4896        NaN  4896
# 5112        NaN  5112
# 5134        NaN  5134
# 5150        NaN  5150
# 5494        NaN  5494
# 5956        NaN  5956
# 6022        NaN  6022
# 6090        NaN  6090
# 6310        NaN  6310
# 6988        NaN  6988
# 7234        NaN  7234
# 7416        NaN  7416
# 7484        NaN  7484
# 7642        NaN  7642
# 8129        NaN  8129
# 8352        NaN  8352
# 8565        NaN  8565
# 8722        NaN  8722
# 8870        NaN  8870
# 9111        NaN  9111
# 9258        NaN  9258
# 9336        NaN  9336
# 9368        NaN  9368
# 9497        NaN  9497
# 9739        NaN  9739
# 9803        NaN  9803
# 9861        NaN  9861
# 9886        NaN  9886
# 9910        NaN  9910
#
# [50 rows x 33 columns]
